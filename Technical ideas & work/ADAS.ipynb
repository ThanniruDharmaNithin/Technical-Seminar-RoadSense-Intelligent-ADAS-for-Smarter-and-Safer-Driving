# %%
import cv2
import numpy as np
import os
from scipy import optimize
from matplotlib import pyplot as plt
from YOLO.YOLO import ObjectDetection_yolo
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[7], line 6
#       4 from scipy import optimize
#       5 from matplotlib import pyplot as plt
# ----> 6 from YOLO.YOLO import ObjectDetection_yolo
#
# ModuleNotFoundError: No module named 'YOLO.YOLO'; 'YOLO' is not a package

# %%
pip install opencv-python
# Out:
# Collecting opencv-python
#   Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl.metadata (20 kB)
# Requirement already satisfied: numpy>=1.21.2 in c:\users\dell\anaconda3\lib\site-packages (from opencv-python) (1.26.4)
# Downloading opencv_python-4.11.0.86-cp37-abi3-win_amd64.whl (39.5 MB)
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.3/39.5 MB ? eta -:--:--
#     --------------------------------------- 0.8/39.5 MB 2.6 MB/s eta 0:00:15
#    - -------------------------------------- 1.6/39.5 MB 3.2 MB/s eta 0:00:12
#    -- ------------------------------------- 2.4/39.5 MB 3.4 MB/s eta 0:00:12
#    --- ------------------------------------ 3.1/39.5 MB 3.5 MB/s eta 0:00:11
#    --- ------------------------------------ 3.9/39.5 MB 3.5 MB/s eta 0:00:11
#    ---- ----------------------------------- 4.7/39.5 MB 3.6 MB/s eta 0:00:10
#    ----- ---------------------------------- 5.8/39.5 MB 3.8 MB/s eta 0:00:09
#    ------ --------------------------------- 6.6/39.5 MB 3.8 MB/s eta 0:00:09
#    ------- -------------------------------- 7.3/39.5 MB 3.8 MB/s eta 0:00:09
#    -------- ------------------------------- 8.1/39.5 MB 3.8 MB/s eta 0:00:09
#    -------- ------------------------------- 8.7/39.5 MB 3.8 MB/s eta 0:00:09
#    --------- ------------------------------ 9.7/39.5 MB 3.8 MB/s eta 0:00:08
#    ---------- ----------------------------- 10.2/39.5 MB 3.8 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.0/39.5 MB 3.7 MB/s eta 0:00:08
#    ----------- ---------------------------- 11.5/39.5 MB 3.7 MB/s eta 0:00:08
#    ------------ --------------------------- 12.1/39.5 MB 3.7 MB/s eta 0:00:08
#    ------------- -------------------------- 13.1/39.5 MB 3.7 MB/s eta 0:00:08
#    -------------- ------------------------- 13.9/39.5 MB 3.6 MB/s eta 0:00:08
#    -------------- ------------------------- 14.4/39.5 MB 3.6 MB/s eta 0:00:07
#    --------------- ------------------------ 15.5/39.5 MB 3.7 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.0/39.5 MB 3.6 MB/s eta 0:00:07
#    ---------------- ----------------------- 16.5/39.5 MB 3.6 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.0/39.5 MB 3.5 MB/s eta 0:00:07
#    ----------------- ---------------------- 17.6/39.5 MB 3.5 MB/s eta 0:00:07
#    ------------------ --------------------- 17.8/39.5 MB 3.4 MB/s eta 0:00:07
#    ------------------ --------------------- 18.1/39.5 MB 3.3 MB/s eta 0:00:07
#    ------------------ --------------------- 18.6/39.5 MB 3.3 MB/s eta 0:00:07
#    ------------------- -------------------- 19.1/39.5 MB 3.3 MB/s eta 0:00:07
#    ------------------- -------------------- 19.7/39.5 MB 3.2 MB/s eta 0:00:07
#    -------------------- ------------------- 20.2/39.5 MB 3.2 MB/s eta 0:00:06
#    --------------------- ------------------ 21.0/39.5 MB 3.2 MB/s eta 0:00:06
#    --------------------- ------------------ 21.5/39.5 MB 3.2 MB/s eta 0:00:06
#    ---------------------- ----------------- 22.3/39.5 MB 3.2 MB/s eta 0:00:06
#    ----------------------- ---------------- 22.8/39.5 MB 3.2 MB/s eta 0:00:06
#    ----------------------- ---------------- 23.3/39.5 MB 3.2 MB/s eta 0:00:06
#    ------------------------ --------------- 23.9/39.5 MB 3.2 MB/s eta 0:00:05
#    ------------------------ --------------- 24.4/39.5 MB 3.2 MB/s eta 0:00:05
#    ------------------------- -------------- 24.9/39.5 MB 3.1 MB/s eta 0:00:05
#    ------------------------- -------------- 25.4/39.5 MB 3.1 MB/s eta 0:00:05
#    -------------------------- ------------- 26.2/39.5 MB 3.1 MB/s eta 0:00:05
#    --------------------------- ------------ 26.7/39.5 MB 3.1 MB/s eta 0:00:05
#    --------------------------- ------------ 27.3/39.5 MB 3.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 27.8/39.5 MB 3.1 MB/s eta 0:00:04
#    ---------------------------- ----------- 28.6/39.5 MB 3.1 MB/s eta 0:00:04
#    ----------------------------- ---------- 29.4/39.5 MB 3.1 MB/s eta 0:00:04
#    ------------------------------ --------- 29.9/39.5 MB 3.1 MB/s eta 0:00:04
#    ------------------------------ --------- 30.4/39.5 MB 3.1 MB/s eta 0:00:03
#    ------------------------------- -------- 31.2/39.5 MB 3.1 MB/s eta 0:00:03
#    -------------------------------- ------- 31.7/39.5 MB 3.1 MB/s eta 0:00:03
#    -------------------------------- ------- 32.5/39.5 MB 3.1 MB/s eta 0:00:03
#    --------------------------------- ------ 33.0/39.5 MB 3.1 MB/s eta 0:00:03
#    ---------------------------------- ----- 33.8/39.5 MB 3.1 MB/s eta 0:00:02
#    ---------------------------------- ----- 34.3/39.5 MB 3.1 MB/s eta 0:00:02
#    ----------------------------------- ---- 35.1/39.5 MB 3.1 MB/s eta 0:00:02
#    ------------------------------------ --- 35.9/39.5 MB 3.1 MB/s eta 0:00:02
#    ------------------------------------- -- 36.7/39.5 MB 3.1 MB/s eta 0:00:01
#    ------------------------------------- -- 37.2/39.5 MB 3.1 MB/s eta 0:00:01
#    -------------------------------------- - 38.0/39.5 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  38.8/39.5 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------  39.3/39.5 MB 3.1 MB/s eta 0:00:01
#    ---------------------------------------- 39.5/39.5 MB 3.1 MB/s eta 0:00:00
# Installing collected packages: opencv-python
# Successfully installed opencv-python-4.11.0.86
# Note: you may need to restart the kernel to use updated packages.

# %%
from LaneDetection.DetectLaneLines import detect_lanes


inp = cv2.imread("road.png")
inp = cv2.cvtColor(inp, cv2.COLOR_BGR2RGB)

out= detect_lanes(inp)
plt.figure(figsize=(15,15))
plt.imshow(out)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 from LaneDetection.DetectLaneLines import detect_lanes
#       4 inp = cv2.imread("imgs/road.png")
#       5 inp = cv2.cvtColor(inp, cv2.COLOR_BGR2RGB)
#
# ModuleNotFoundError: No module named 'LaneDetection'

# %%
out,x = ObjectDetection_yolo(out)

out = cv2.cvtColor(out, cv2.COLOR_BGR2RGB)
plt.figure(figsize=(10,10))
plt.imshow(out)
plt.show()
